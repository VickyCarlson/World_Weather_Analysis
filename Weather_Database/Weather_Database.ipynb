# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
import json
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations. Declare each array as a variable.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.Unpack the zip object into a list so that you only have to create it once.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. Use Enumerate 
#method to get the index of hte city and the city to create an endpoint URL.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | bilma
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | port blair
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | dunedin
# Processing Record 7 of Set 1 | asfi
# Processing Record 8 of Set 1 | anda
# Processing Record 9 of Set 1 | sarai
# Processing Record 10 of Set 1 | port macquarie
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | fort-shevchenko
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | chudey
# Processing Record 24 of Set 1 | san quintin
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | svetlaya
# Processing Record 27 of Set 1 | santiago del estero
# Processing Record 28 of Set 1 | shache
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | jaru
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | rawson
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | gizo
# Processing Record 37 of Set 1 | buchanan
# Processing Record 38 of Set 1 | verkhnevilyuysk
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | calabazar de sagua
# Processing Record 41 of Set 1 | gavle
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | acajutla
# Processing Record 46 of Set 1 | ixtapa
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | solnechnyy
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | chake chake
# Processing Record 2 of Set 2 | bundaberg
# Processing Record 3 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 2 | vanavara
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | ostrovnoy
# Processing Record 10 of Set 2 | omboue
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | north bend
# Processing Record 17 of Set 2 | canon city
# Processing Record 18 of Set 2 | berislavesti
# Processing Record 19 of Set 2 | taoudenni
# Processing Record 20 of Set 2 | ponta delgada
# Processing Record 21 of Set 2 | maceio
# Processing Record 22 of Set 2 | sisimiut
# Processing Record 23 of Set 2 | sao miguel do araguaia
# Processing Record 24 of Set 2 | mouila
# Processing Record 25 of Set 2 | ivolginsk
# Processing Record 26 of Set 2 | marsh harbour
# Processing Record 27 of Set 2 | yuzhno-sukhokumsk
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | caucaia
# Processing Record 30 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | herat
# Processing Record 33 of Set 2 | sao francisco
# Processing Record 34 of Set 2 | xam nua
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | half moon bay
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | vila franca do campo
# Processing Record 39 of Set 2 | vavuniya
# Processing Record 40 of Set 2 | kismayo
# Processing Record 41 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | axim
# Processing Record 43 of Set 2 | tucumcari
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | sikasso
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | pacific grove
# Processing Record 49 of Set 2 | surt
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | huangyan
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | haimen
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | estelle
# Processing Record 6 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 7 of Set 3 | laguna
# Processing Record 8 of Set 3 | norman wells
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | monchegorsk
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | praia
# Processing Record 14 of Set 3 | la ronge
# Processing Record 15 of Set 3 | samarai
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | mandalgovi
# Processing Record 18 of Set 3 | pangnirtung
# Processing Record 19 of Set 3 | bougouni
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | kattivakkam
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | umm kaddadah
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | port-gentil
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | auki
# Processing Record 30 of Set 3 | nyurba
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | finote selam
# Processing Record 34 of Set 3 | olafsvik
# Processing Record 35 of Set 3 | bonthe
# Processing Record 36 of Set 3 | semirom
# Processing Record 37 of Set 3 | ananindeua
# Processing Record 38 of Set 3 | san jose
# Processing Record 39 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 3 | newcastle
# Processing Record 41 of Set 3 | posse
# Processing Record 42 of Set 3 | mirnyy
# Processing Record 43 of Set 3 | guerrero negro
# Processing Record 44 of Set 3 | asosa
# Processing Record 45 of Set 3 | harper
# Processing Record 46 of Set 3 | shimoda
# Processing Record 47 of Set 3 | flin flon
# Processing Record 48 of Set 3 | makakilo city
# Processing Record 49 of Set 3 | bonfim
# Processing Record 50 of Set 3 | oxford
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | castro
# Processing Record 3 of Set 4 | aquiraz
# Processing Record 4 of Set 4 | namibe
# Processing Record 5 of Set 4 | vytegra
# Processing Record 6 of Set 4 | rafraf
# Processing Record 7 of Set 4 | dudinka
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | hilo
# Processing Record 10 of Set 4 | serra talhada
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | tezpur
# Processing Record 15 of Set 4 | takoradi
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | kysyl-syr
# Processing Record 18 of Set 4 | nelson bay
# Processing Record 19 of Set 4 | garh maharaja
# Processing Record 20 of Set 4 | dingle
# Processing Record 21 of Set 4 | sao jose da coroa grande
# Processing Record 22 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 4 | yar-sale
# Processing Record 24 of Set 4 | salvador
# Processing Record 25 of Set 4 | padang
# Processing Record 26 of Set 4 | masvingo
# Processing Record 27 of Set 4 | amapa
# Processing Record 28 of Set 4 | ancud
# Processing Record 29 of Set 4 | dhidhdhoo
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | kiunga
# Processing Record 32 of Set 4 | korla
# Processing Record 33 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 4 | tarata
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | aripuana
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 4 | hervey bay
# Processing Record 41 of Set 4 | sinnamary
# Processing Record 42 of Set 4 | ambilobe
# Processing Record 43 of Set 4 | bredasdorp
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | cape town
# Processing Record 46 of Set 4 | manoel urbano
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | cervo
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | flinders
# Processing Record 1 of Set 5 | zima
# Processing Record 2 of Set 5 | kimbe
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | santa maria
# Processing Record 5 of Set 5 | karksi-nuia
# Processing Record 6 of Set 5 | safaqis
# City not found. Skipping...
# Processing Record 7 of Set 5 | berlevag
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | bayan
# Processing Record 10 of Set 5 | gat
# Processing Record 11 of Set 5 | saskylakh
# Processing Record 12 of Set 5 | san vicente
# Processing Record 13 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 14 of Set 5 | umm lajj
# Processing Record 15 of Set 5 | narsaq
# Processing Record 16 of Set 5 | mazagao
# Processing Record 17 of Set 5 | balkanabat
# Processing Record 18 of Set 5 | oda
# Processing Record 19 of Set 5 | qaqortoq
# Processing Record 20 of Set 5 | elbrus
# Processing Record 21 of Set 5 | salinopolis
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | tari
# Processing Record 24 of Set 5 | malakal
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | taldan
# Processing Record 27 of Set 5 | gwadar
# Processing Record 28 of Set 5 | tura
# Processing Record 29 of Set 5 | coahuayana
# Processing Record 30 of Set 5 | tautira
# Processing Record 31 of Set 5 | heemstede
# Processing Record 32 of Set 5 | vuktyl
# Processing Record 33 of Set 5 | buala
# Processing Record 34 of Set 5 | kaitangata
# Processing Record 35 of Set 5 | fremont
# Processing Record 36 of Set 5 | kloulklubed
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | mitchell
# Processing Record 39 of Set 5 | belaya kholunitsa
# Processing Record 40 of Set 5 | meadow lake
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | ambovombe
# Processing Record 43 of Set 5 | upington
# Processing Record 44 of Set 5 | lilongwe
# Processing Record 45 of Set 5 | ilulissat
# Processing Record 46 of Set 5 | hithadhoo
# Processing Record 47 of Set 5 | alice town
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 5 | kieta
# Processing Record 1 of Set 6 | pictou
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | savannah bight
# Processing Record 4 of Set 6 | yulara
# Processing Record 5 of Set 6 | wajima
# Processing Record 6 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | evanston
# Processing Record 9 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 6 | livny
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | banda aceh
# Processing Record 13 of Set 6 | carlagan
# Processing Record 14 of Set 6 | ribeira grande
# Processing Record 15 of Set 6 | isangel
# Processing Record 16 of Set 6 | san cristobal
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | marsa matruh
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | tateyama
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | americus
# Processing Record 23 of Set 6 | brokopondo
# Processing Record 24 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 6 | marzuq
# Processing Record 26 of Set 6 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 27 of Set 6 | kiruna
# Processing Record 28 of Set 6 | salinas
# Processing Record 29 of Set 6 | portland
# Processing Record 30 of Set 6 | mbour
# Processing Record 31 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | agua verde
# Processing Record 34 of Set 6 | monduli
# Processing Record 35 of Set 6 | manzhouli
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | san
# Processing Record 38 of Set 6 | nara
# Processing Record 39 of Set 6 | haines junction
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | juneau
# Processing Record 42 of Set 6 | la rioja
# Processing Record 43 of Set 6 | kavieng
# Processing Record 44 of Set 6 | talnakh
# Processing Record 45 of Set 6 | kansk
# Processing Record 46 of Set 6 | sitka
# Processing Record 47 of Set 6 | riyadh
# Processing Record 48 of Set 6 | yermakovskoye
# Processing Record 49 of Set 6 | bone
# Processing Record 50 of Set 6 | tiarei
# Processing Record 1 of Set 7 | naryan-mar
# Processing Record 2 of Set 7 | goedereede
# Processing Record 3 of Set 7 | prince rupert
# Processing Record 4 of Set 7 | camacha
# Processing Record 5 of Set 7 | cockburn town
# Processing Record 6 of Set 7 | puerto quijarro
# Processing Record 7 of Set 7 | port elizabeth
# Processing Record 8 of Set 7 | namatanai
# Processing Record 9 of Set 7 | asilah
# Processing Record 10 of Set 7 | hamilton
# Processing Record 11 of Set 7 | quatre cocos
# Processing Record 12 of Set 7 | seoul
# Processing Record 13 of Set 7 | torbay
# Processing Record 14 of Set 7 | husavik
# Processing Record 15 of Set 7 | simplicio mendes
# Processing Record 16 of Set 7 | newport
# Processing Record 17 of Set 7 | capoterra
# Processing Record 18 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 7 | ilheus
# Processing Record 21 of Set 7 | saldanha
# Processing Record 22 of Set 7 | sechura
# Processing Record 23 of Set 7 | hurghada
# Processing Record 24 of Set 7 | forest grove
# Processing Record 25 of Set 7 | thio
# Processing Record 26 of Set 7 | manchester
# Processing Record 27 of Set 7 | igrim
# Processing Record 28 of Set 7 | asau
# Processing Record 29 of Set 7 | charleston
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | gaspe
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 7 | cumana
# Processing Record 35 of Set 7 | poum
# Processing Record 36 of Set 7 | alibag
# Processing Record 37 of Set 7 | caravelas
# Processing Record 38 of Set 7 | xichang
# Processing Record 39 of Set 7 | cooma
# Processing Record 40 of Set 7 | matara
# Processing Record 41 of Set 7 | lagos
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | katha
# City not found. Skipping...
# Processing Record 46 of Set 7 | funadhoo
# Processing Record 47 of Set 7 | dikson
# Processing Record 48 of Set 7 | saint-joseph
# Processing Record 49 of Set 7 | bosaso
# Processing Record 50 of Set 7 | taltal
# Processing Record 1 of Set 8 | montepuez
# Processing Record 2 of Set 8 | warah
# Processing Record 3 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 8 | rondonopolis
# Processing Record 5 of Set 8 | samagaltay
# Processing Record 6 of Set 8 | aguimes
# Processing Record 7 of Set 8 | kirsanov
# Processing Record 8 of Set 8 | nabire
# Processing Record 9 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 8 | pisco
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | puerto baquerizo moreno
# Processing Record 13 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 8 | marakkanam
# Processing Record 15 of Set 8 | waingapu
# Processing Record 16 of Set 8 | tokzar
# City not found. Skipping...
# Processing Record 17 of Set 8 | ushtobe
# Processing Record 18 of Set 8 | cota
# Processing Record 19 of Set 8 | rocha
# Processing Record 20 of Set 8 | kudahuvadhoo
# Processing Record 21 of Set 8 | houma
# Processing Record 22 of Set 8 | inuvik
# Processing Record 23 of Set 8 | ozernovskiy
# Processing Record 24 of Set 8 | naustdal
# Processing Record 25 of Set 8 | xining
# Processing Record 26 of Set 8 | katobu
# Processing Record 27 of Set 8 | revelstoke
# Processing Record 28 of Set 8 | batagay-alyta
# Processing Record 29 of Set 8 | avera
# Processing Record 30 of Set 8 | calamar
# Processing Record 31 of Set 8 | bengkulu
# Processing Record 32 of Set 8 | ahuimanu
# Processing Record 33 of Set 8 | udachnyy
# Processing Record 34 of Set 8 | maumere
# Processing Record 35 of Set 8 | tome-acu
# City not found. Skipping...
# Processing Record 36 of Set 8 | kargat
# Processing Record 37 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 38 of Set 8 | carthage
# Processing Record 39 of Set 8 | iracoubo
# Processing Record 40 of Set 8 | kondinskoye
# Processing Record 41 of Set 8 | singaraja
# Processing Record 42 of Set 8 | mananjary
# Processing Record 43 of Set 8 | buloh kasap
# Processing Record 44 of Set 8 | qasigiannguit
# Processing Record 45 of Set 8 | bagdarin
# Processing Record 46 of Set 8 | mnogovershinnyy
# Processing Record 47 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 48 of Set 8 | lasa
# Processing Record 49 of Set 8 | san policarpo
# Processing Record 50 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 9 | atar
# Processing Record 2 of Set 9 | parabel
# Processing Record 3 of Set 9 | slonim
# Processing Record 4 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 9 | jinxiang
# Processing Record 6 of Set 9 | kefamenanu
# Processing Record 7 of Set 9 | rudnogorsk
# Processing Record 8 of Set 9 | jaguaruana
# Processing Record 9 of Set 9 | krasnyy chikoy
# Processing Record 10 of Set 9 | byron bay
# Processing Record 11 of Set 9 | lorengau
# Processing Record 12 of Set 9 | stepnoye
# Processing Record 13 of Set 9 | lethem
# Processing Record 14 of Set 9 | buluang
# Processing Record 15 of Set 9 | sao joao da barra
# Processing Record 16 of Set 9 | adrar
# Processing Record 17 of Set 9 | temuco
# Processing Record 18 of Set 9 | segou
# Processing Record 19 of Set 9 | tingo maria
# Processing Record 20 of Set 9 | kelheim
# Processing Record 21 of Set 9 | lompoc
# Processing Record 22 of Set 9 | deder
# Processing Record 23 of Set 9 | khristoforovo
# City not found. Skipping...
# Processing Record 24 of Set 9 | clyde river
# Processing Record 25 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 26 of Set 9 | gainza
# Processing Record 27 of Set 9 | kupang
# Processing Record 28 of Set 9 | narasannapeta
# Processing Record 29 of Set 9 | ajdabiya
# Processing Record 30 of Set 9 | shumikha
# Processing Record 31 of Set 9 | arroio grande
# Processing Record 32 of Set 9 | denpasar
# Processing Record 33 of Set 9 | grand gaube
# Processing Record 34 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 9 | demba
# Processing Record 36 of Set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | nichinan
# Processing Record 38 of Set 9 | bathurst
# Processing Record 39 of Set 9 | biak
# Processing Record 40 of Set 9 | mount gambier
# Processing Record 41 of Set 9 | karratha
# Processing Record 42 of Set 9 | bathsheba
# Processing Record 43 of Set 9 | mecca
# Processing Record 44 of Set 9 | cherskiy
# Processing Record 45 of Set 9 | deer lake
# Processing Record 46 of Set 9 | rampura
# Processing Record 47 of Set 9 | ulkan
# Processing Record 48 of Set 9 | san carlos de bariloche
# Processing Record 49 of Set 9 | batagay
# Processing Record 50 of Set 9 | zhovkva
# Processing Record 1 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 10 | malanje
# Processing Record 3 of Set 10 | trat
# Processing Record 4 of Set 10 | verkh-usugli
# Processing Record 5 of Set 10 | dalvik
# Processing Record 6 of Set 10 | kambove
# Processing Record 7 of Set 10 | geraldton
# Processing Record 8 of Set 10 | port maria
# Processing Record 9 of Set 10 | lesnoy
# Processing Record 10 of Set 10 | jalu
# Processing Record 11 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 10 | sioux lookout
# Processing Record 13 of Set 10 | gamba
# Processing Record 14 of Set 10 | tuatapere
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | derzhavinsk
# Processing Record 17 of Set 10 | saint george
# Processing Record 18 of Set 10 | loandjili
# Processing Record 19 of Set 10 | bainbridge
# Processing Record 20 of Set 10 | sterling
# Processing Record 21 of Set 10 | nioro
# Processing Record 22 of Set 10 | bagrami
# Processing Record 23 of Set 10 | botou
# Processing Record 24 of Set 10 | sakete
# Processing Record 25 of Set 10 | chokwe
# Processing Record 26 of Set 10 | contai
# Processing Record 27 of Set 10 | dire
# Processing Record 28 of Set 10 | beppu
# Processing Record 29 of Set 10 | paka
# Processing Record 30 of Set 10 | vao
# Processing Record 31 of Set 10 | agualote
# Processing Record 32 of Set 10 | kibara
# Processing Record 33 of Set 10 | murdochville
# Processing Record 34 of Set 10 | isilkul
# Processing Record 35 of Set 10 | fortuna
# Processing Record 36 of Set 10 | cabedelo
# Processing Record 37 of Set 10 | college
# Processing Record 38 of Set 10 | port hedland
# Processing Record 39 of Set 10 | sidney
# Processing Record 40 of Set 10 | sol-iletsk
# Processing Record 41 of Set 10 | talcahuano
# Processing Record 42 of Set 10 | beloha
# Processing Record 43 of Set 10 | pidhorodne
# Processing Record 44 of Set 10 | trapani
# Processing Record 45 of Set 10 | catalao
# Processing Record 46 of Set 10 | beira
# Processing Record 47 of Set 10 | moose factory
# Processing Record 48 of Set 10 | fare
# Processing Record 49 of Set 10 | kitimat
# Processing Record 50 of Set 10 | norfolk
# Processing Record 1 of Set 11 | yekaterinoslavka
# Processing Record 2 of Set 11 | yerbogachen
# Processing Record 3 of Set 11 | naze
# Processing Record 4 of Set 11 | campbell river
# Processing Record 5 of Set 11 | senges
# Processing Record 6 of Set 11 | vestmannaeyjar
# Processing Record 7 of Set 11 | podgorica
# Processing Record 8 of Set 11 | murgab
# Processing Record 9 of Set 11 | hofn
# Processing Record 10 of Set 11 | caxias
# Processing Record 11 of Set 11 | nalut
# Processing Record 12 of Set 11 | sabha
# Processing Record 13 of Set 11 | nevsehir
# Processing Record 14 of Set 11 | pacifica
# Processing Record 15 of Set 11 | humaita
# Processing Record 16 of Set 11 | severo-kurilsk
# Processing Record 17 of Set 11 | gilbues
# Processing Record 18 of Set 11 | sembakung
# Processing Record 19 of Set 11 | puerto leguizamo
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | yeppoon
# Processing Record 22 of Set 11 | pa sang
# Processing Record 23 of Set 11 | shadrinsk
# Processing Record 24 of Set 11 | palembang
# Processing Record 25 of Set 11 | broome
# Processing Record 26 of Set 11 | hadishahr
# Processing Record 27 of Set 11 | tromso
# Processing Record 28 of Set 11 | esso
# Processing Record 29 of Set 11 | chapleau
# Processing Record 30 of Set 11 | cabatuan
# Processing Record 31 of Set 11 | oum hadjer
# Processing Record 32 of Set 11 | okhotsk
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | jitauna
# Processing Record 35 of Set 11 | lazaro cardenas
# Processing Record 36 of Set 11 | waddan
# Processing Record 37 of Set 11 | lakselv
# Processing Record 38 of Set 11 | jiazi
# Processing Record 39 of Set 11 | jacqueville
# Processing Record 40 of Set 11 | kamenka
# Processing Record 41 of Set 11 | yumen
# Processing Record 42 of Set 11 | forssa
# Processing Record 43 of Set 11 | kyren
# Processing Record 44 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 11 | mehamn
# Processing Record 46 of Set 11 | chilliwack
# Processing Record 47 of Set 11 | petauke
# Processing Record 48 of Set 11 | boende
# Processing Record 49 of Set 11 | mugur-aksy
# Processing Record 50 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 12 | buzmeyin
# Processing Record 2 of Set 12 | halifax
# Processing Record 3 of Set 12 | entre rios
# Processing Record 4 of Set 12 | kamarion
# Processing Record 5 of Set 12 | monrovia
# Processing Record 6 of Set 12 | kutulik
# Processing Record 7 of Set 12 | tambura
# Processing Record 8 of Set 12 | rorvik
# Processing Record 9 of Set 12 | killybegs
# Processing Record 10 of Set 12 | san-pedro
# Processing Record 11 of Set 12 | goure
# Processing Record 12 of Set 12 | raahe
# Processing Record 13 of Set 12 | egvekinot
# Processing Record 14 of Set 12 | constitucion
# Processing Record 15 of Set 12 | nicoya
# Processing Record 16 of Set 12 | santa maria del oro
# Processing Record 17 of Set 12 | vryburg
# Processing Record 18 of Set 12 | sambava
# Processing Record 19 of Set 12 | mpika
# Processing Record 20 of Set 12 | tabuk
# Processing Record 21 of Set 12 | uruzgan
# Processing Record 22 of Set 12 | lunguletu
# Processing Record 23 of Set 12 | kencong
# Processing Record 24 of Set 12 | las cruces
# Processing Record 25 of Set 12 | saint-pierre
# Processing Record 26 of Set 12 | pirgos
# Processing Record 27 of Set 12 | nassjo
# Processing Record 28 of Set 12 | dongsheng
# Processing Record 29 of Set 12 | birao
# Processing Record 30 of Set 12 | imeni poliny osipenko
# Processing Record 31 of Set 12 | itoman
# Processing Record 32 of Set 12 | methven
# Processing Record 33 of Set 12 | kavaratti
# Processing Record 34 of Set 12 | gisborne
# Processing Record 35 of Set 12 | bhuban
# Processing Record 36 of Set 12 | todos santos
# Processing Record 37 of Set 12 | merauke
# Processing Record 38 of Set 12 | yerofey pavlovich
# Processing Record 39 of Set 12 | mizan teferi
# Processing Record 40 of Set 12 | lodja
# Processing Record 41 of Set 12 | seminole
# Processing Record 42 of Set 12 | izhma
# Processing Record 43 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 44 of Set 12 | quelimane
# Processing Record 45 of Set 12 | garowe
# Processing Record 46 of Set 12 | sarangani
# Processing Record 47 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 12 | sennoy
# Processing Record 49 of Set 12 | khrustalnyy
# City not found. Skipping...
# Processing Record 50 of Set 12 | toora-khem
# Processing Record 1 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 13 | san andres
# Processing Record 3 of Set 13 | puerto escondido
# Processing Record 4 of Set 13 | lima
# Processing Record 5 of Set 13 | zelenoborsk
# Processing Record 6 of Set 13 | leh
# Processing Record 7 of Set 13 | surok
# Processing Record 8 of Set 13 | puerto del rosario
# Processing Record 9 of Set 13 | pombia
# Processing Record 10 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 11 of Set 13 | sayat
# Processing Record 12 of Set 13 | thanatpin
# Processing Record 13 of Set 13 | kaeo
# Processing Record 14 of Set 13 | kungurtug
# Processing Record 15 of Set 13 | labrea
# Processing Record 16 of Set 13 | wladyslawowo
# Processing Record 17 of Set 13 | nanortalik
# Processing Record 18 of Set 13 | lata
# Processing Record 19 of Set 13 | moshi
# Processing Record 20 of Set 13 | puerto princesa
# Processing Record 21 of Set 13 | cayenne
# Processing Record 22 of Set 13 | vanersborg
# Processing Record 23 of Set 13 | henties bay
# Processing Record 24 of Set 13 | blagoyevo
# Processing Record 25 of Set 13 | beringovskiy
# Processing Record 26 of Set 13 | miri
# Processing Record 27 of Set 13 | vazante
# Processing Record 28 of Set 13 | camabatela
# Processing Record 29 of Set 13 | yarada
# Processing Record 30 of Set 13 | maarianhamina
# Processing Record 31 of Set 13 | wanxian
# Processing Record 32 of Set 13 | puerto cabezas
# Processing Record 33 of Set 13 | fort nelson
# Processing Record 34 of Set 13 | natal
# Processing Record 35 of Set 13 | aras
# Processing Record 36 of Set 13 | muravlenko
# Processing Record 37 of Set 13 | morros
# Processing Record 38 of Set 13 | comodoro rivadavia
# Processing Record 39 of Set 13 | santa marta
# Processing Record 40 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 41 of Set 13 | barisal
# Processing Record 42 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 43 of Set 13 | mackay
# Processing Record 44 of Set 13 | iberia
# Processing Record 45 of Set 13 | touros
# Processing Record 46 of Set 13 | fairbanks
# Processing Record 47 of Set 13 | cochrane
# Processing Record 48 of Set 13 | develi
# Processing Record 49 of Set 13 | state college
# Processing Record 50 of Set 13 | bogomila
# Processing Record 1 of Set 14 | borogontsy
# Processing Record 2 of Set 14 | korem
# Processing Record 3 of Set 14 | los llanos de aridane
# Processing Record 4 of Set 14 | plettenberg bay
# Processing Record 5 of Set 14 | mursalimkino
# Processing Record 6 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 14 | aswan
# Processing Record 8 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 14 | cidreira
# Processing Record 10 of Set 14 | goderich
# Processing Record 11 of Set 14 | namwala
# Processing Record 12 of Set 14 | bowen
# Processing Record 13 of Set 14 | preobrazheniye
# Processing Record 14 of Set 14 | virden
# Processing Record 15 of Set 14 | praia da vitoria
# Processing Record 16 of Set 14 | tahe
# Processing Record 17 of Set 14 | maturin
# Processing Record 18 of Set 14 | gboko
# Processing Record 19 of Set 14 | ahipara
# Processing Record 20 of Set 14 | chinchani
# Processing Record 21 of Set 14 | mareeba
# Processing Record 22 of Set 14 | arman
# Processing Record 23 of Set 14 | severodvinsk
# Processing Record 24 of Set 14 | kerman
# Processing Record 25 of Set 14 | zhigansk
# Processing Record 26 of Set 14 | siwani
# City not found. Skipping...
# Processing Record 27 of Set 14 | sorland
# Processing Record 28 of Set 14 | atsiki
# City not found. Skipping...
# Processing Record 29 of Set 14 | azar shahr
# City not found. Skipping...
# Processing Record 30 of Set 14 | baherden
# Processing Record 31 of Set 14 | faanui
# Processing Record 32 of Set 14 | mana
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | brae
# Processing Record 35 of Set 14 | itaituba
# Processing Record 36 of Set 14 | dalbandin
# Processing Record 37 of Set 14 | semey
# Processing Record 38 of Set 14 | vallenar
# Processing Record 39 of Set 14 | praya
# Processing Record 40 of Set 14 | say
# Processing Record 41 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 14 | huaral
# Processing Record 43 of Set 14 | sakakah
# Processing Record 44 of Set 14 | goma
# Processing Record 45 of Set 14 | itacare
# Processing Record 46 of Set 14 | tumpat
# Processing Record 47 of Set 14 | nouakchott
# Processing Record 48 of Set 14 | diapaga
# Processing Record 49 of Set 14 | ballina
# Processing Record 50 of Set 14 | isabela
# Processing Record 1 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 2 of Set 15 | sao raimundo das mangabeiras
# Processing Record 3 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 15 | vieste
# Processing Record 5 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 15 | lensk
# Processing Record 7 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 8 of Set 15 | banikoara
# Processing Record 9 of Set 15 | basco
# Processing Record 10 of Set 15 | kidal
# Processing Record 11 of Set 15 | bam
# Processing Record 12 of Set 15 | westport
# Processing Record 13 of Set 15 | phumi samraong
# City not found. Skipping...
# Processing Record 14 of Set 15 | pauini
# Processing Record 15 of Set 15 | chapais
# Processing Record 16 of Set 15 | campina verde
# Processing Record 17 of Set 15 | itabirito
# Processing Record 18 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 15 | freetown
# Processing Record 20 of Set 15 | lumphat
# Processing Record 21 of Set 15 | ribas do rio pardo
# Processing Record 22 of Set 15 | koutiala
# Processing Record 23 of Set 15 | broken hill
# Processing Record 24 of Set 15 | birjand
# Processing Record 25 of Set 15 | isla vista
# Processing Record 26 of Set 15 | teguise
# Processing Record 27 of Set 15 | tungor
# Processing Record 28 of Set 15 | kathu
# Processing Record 29 of Set 15 | nassau
# Processing Record 30 of Set 15 | labuhan
# Processing Record 31 of Set 15 | armidale
# Processing Record 32 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 15 | silver city
# Processing Record 34 of Set 15 | nizhnevartovsk
# Processing Record 35 of Set 15 | palauig
# Processing Record 36 of Set 15 | nakatunguru
# Processing Record 37 of Set 15 | thinadhoo
# Processing Record 38 of Set 15 | altamira
# Processing Record 39 of Set 15 | itarema
# Processing Record 40 of Set 15 | ascension
# Processing Record 41 of Set 15 | waw
# Processing Record 42 of Set 15 | maningrida
# Processing Record 43 of Set 15 | necochea
# Processing Record 44 of Set 15 | homer
# Processing Record 45 of Set 15 | mezhdurechensk
# Processing Record 46 of Set 15 | komsomolskiy
# Processing Record 47 of Set 15 | bairiki
# Processing Record 48 of Set 15 | ballstad
# City not found. Skipping...
# Processing Record 49 of Set 15 | panzhihua
# Processing Record 50 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 16 | mayor pablo lagerenza
# Processing Record 2 of Set 16 | sozimskiy
# Processing Record 3 of Set 16 | klyuchi
# Processing Record 4 of Set 16 | amuntai
# Processing Record 5 of Set 16 | kapoeta
# Processing Record 6 of Set 16 | saint-hyacinthe
# Processing Record 7 of Set 16 | madera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     31.66        93          75
# 1           Bilma      NE  18.6853   12.9164     86.40        34         100
# 2    Port Lincoln      AU -34.7333  135.8667     52.36        80          16
# 3      Port Blair      IN  11.6667   92.7500     80.15        88          94
# 4        Khatanga      RU  71.9667  102.5000     11.39        94         100
# 5         Dunedin      NZ -45.8742  170.5036     52.81        79         100
# 6            Asfi      MA  32.2994   -9.2372     70.32        72          32
# 7            Anda      CN  46.4000  125.3167     23.95        44           6
# 8           Sarai      RU  53.7458   41.0213     50.04        53         100
# 9  Port Macquarie      AU -31.4333  152.9167     48.88        71           2
#
#    Wind Speed Current Description
# 0       36.82          light snow
# 1        8.63     overcast clouds
# 2        7.87          few clouds
# 3       14.61     overcast clouds
# 4        7.70     overcast clouds
# 5       13.00     overcast clouds
# 6       19.10    scattered clouds
# 7        8.03           clear sky
# 8       12.59     overcast clouds
# 9        5.21           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
